# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("/home/giteshgoyal/Documents/Jnotebooks/iris.csv")

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
df = iris.copy()

# %%
df.head(30)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (150, 5)
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df["sepal.length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %%
df.isnull().sum()  #showing sum of how many null enrties in each column
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.iloc[1:5,2:5]    #accessing rows and columns
# Out:
#    petal.length  petal.width variety
# 1           1.4          0.2  Setosa
# 2           1.3          0.2  Setosa
# 3           1.5          0.2  Setosa
# 4           1.4          0.2  Setosa

# %%
a = df.drop(1)  # first row is deleted and new df stored in a
a
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [148 rows x 5 columns]

# %%
df.drop(0,inplace=True)  # 1st row is dropped and changes store in df itself
# removed 0th label row
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [149 rows x 5 columns]

# %%
df.drop(df.index[[0,2]],inplace=True) # removed 1st two rows by position not labels
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 2             4.7          3.2           1.3          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [147 rows x 5 columns]

# %%
df["sepal.length"] > 5
# Out:
# 2      False
# 4      False
# 5       True
# 6      False
# 7      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: sepal.length, Length: 147, dtype: bool

# %%
df[df["sepal.length"] > 5]  # getting only those entries where condition is true (boolean indexing)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 5             5.4          3.9           1.7          0.4     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 14            5.8          4.0           1.2          0.2     Setosa
# 15            5.7          4.4           1.5          0.4     Setosa
# 16            5.4          3.9           1.3          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [117 rows x 5 columns]

# %%
c1 = df[df["variety"] == 'Virginica']
c1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
c1.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
print(df.iloc[0])  #by position
# Out:
# sepal.length       4.7
# sepal.width        3.2
# petal.length       1.3
# petal.width        0.2
# variety         Setosa
# Name: 2, dtype: object

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 2           4.7          3.2           1.3          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
df.loc[2]  # by label
# Out:
# sepal.length       4.7
# sepal.width        3.2
# petal.length       1.3
# petal.width        0.2
# variety         Setosa
# Name: 2, dtype: object

# %%
df.loc[0] = [1.5,4.5,2.0,0.5,'Setosa']

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 2           4.7          3.2           1.3          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
df.tail()   #our newly created entry by default add in the end
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
# 0             1.5          4.5           2.0          0.5     Setosa

# %%
df.reset_index()  # creating a new column of previous indexes(default drop value is false)
# Out:
#      index  sepal.length  sepal.width  petal.length  petal.width    variety
# 0        2           4.7          3.2           1.3          0.2     Setosa
# 1        4           5.0          3.6           1.4          0.2     Setosa
# 2        5           5.4          3.9           1.7          0.4     Setosa
# 3        6           4.6          3.4           1.4          0.3     Setosa
# 4        7           5.0          3.4           1.5          0.2     Setosa
# ..     ...           ...          ...           ...          ...        ...
# 143    146           6.3          2.5           5.0          1.9  Virginica
# 144    147           6.5          3.0           5.2          2.0  Virginica
# 145    148           6.2          3.4           5.4          2.3  Virginica
# 146    149           5.9          3.0           5.1          1.8  Virginica
# 147      0           1.5          4.5           2.0          0.5     Setosa
#
# [148 rows x 6 columns]

# %%
df.reset_index(drop=True,inplace=True)  #drop true means no column of previous index

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             4.7          3.2           1.3          0.2     Setosa
# 1             5.0          3.6           1.4          0.2     Setosa
# 2             5.4          3.9           1.7          0.4     Setosa
# 3             4.6          3.4           1.4          0.3     Setosa
# 4             5.0          3.4           1.5          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 143           6.3          2.5           5.0          1.9  Virginica
# 144           6.5          3.0           5.2          2.0  Virginica
# 145           6.2          3.4           5.4          2.3  Virginica
# 146           5.9          3.0           5.1          1.8  Virginica
# 147           1.5          4.5           2.0          0.5     Setosa
#
# [148 rows x 5 columns]

# %%
# drop a column
df2 = df.drop('sepal.length',axis = 1)
df2
# Out:
#      sepal.width  petal.length  petal.width    variety
# 0            3.2           1.3          0.2     Setosa
# 1            3.6           1.4          0.2     Setosa
# 2            3.9           1.7          0.4     Setosa
# 3            3.4           1.4          0.3     Setosa
# 4            3.4           1.5          0.2     Setosa
# ..           ...           ...          ...        ...
# 143          2.5           5.0          1.9  Virginica
# 144          3.0           5.2          2.0  Virginica
# 145          3.4           5.4          2.3  Virginica
# 146          3.0           5.1          1.8  Virginica
# 147          4.5           2.0          0.5     Setosa
#
# [148 rows x 4 columns]

# %%
df = iris.copy()
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df['sdiff'] = df['sepal.length'] - df['sepal.width']   # adding a column as diff of sepal length and sepal width
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  sdiff
# 0             5.1          3.5           1.4          0.2     Setosa    1.6
# 1             4.9          3.0           1.4          0.2     Setosa    1.9
# 2             4.7          3.2           1.3          0.2     Setosa    1.5
# 3             4.6          3.1           1.5          0.2     Setosa    1.5
# 4             5.0          3.6           1.4          0.2     Setosa    1.4
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  Virginica    3.7
# 146           6.3          2.5           5.0          1.9  Virginica    3.8
# 147           6.5          3.0           5.2          2.0  Virginica    3.5
# 148           6.2          3.4           5.4          2.3  Virginica    2.8
# 149           5.9          3.0           5.1          1.8  Virginica    2.9
#
# [150 rows x 6 columns]

# %%
df['pdiff'] = df['petal.length'] - df['petal.width']
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  sdiff  \
# 0             5.1          3.5           1.4          0.2     Setosa    1.6
# 1             4.9          3.0           1.4          0.2     Setosa    1.9
# 2             4.7          3.2           1.3          0.2     Setosa    1.5
# 3             4.6          3.1           1.5          0.2     Setosa    1.5
# 4             5.0          3.6           1.4          0.2     Setosa    1.4
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  Virginica    3.7
# 146           6.3          2.5           5.0          1.9  Virginica    3.8
# 147           6.5          3.0           5.2          2.0  Virginica    3.5
# 148           6.2          3.4           5.4          2.3  Virginica    2.8
# 149           5.9          3.0           5.1          1.8  Virginica    2.9
#
#      pdiff
# 0      1.2
# 1      1.2
# 2      1.1
# ...

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width       sdiff  \
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    2.786000
# std        0.828066     0.435866      1.765298     0.762238    0.980072
# min        4.300000     2.000000      1.000000     0.100000    1.000000
# 25%        5.100000     2.800000      1.600000     0.300000    1.800000
# 50%        5.800000     3.000000      4.350000     1.300000    3.000000
# 75%        6.400000     3.300000      5.100000     1.800000    3.600000
# max        7.900000     4.400000      6.900000     2.500000    5.100000
#
#             pdiff
# count  150.000000
# mean     2.558667
# std      1.051696
# min      0.800000
# 25%      1.300000
# 50%      2.900000
# 75%      3.300000
# max      4.700000

# %%
# handling nan entries
df.iloc[2:4,1:3] = np.nan   #creating nan entries
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  sdiff  pdiff
# 0           5.1          3.5           1.4          0.2  Setosa    1.6    1.2
# 1           4.9          3.0           1.4          0.2  Setosa    1.9    1.2
# 2           4.7          NaN           NaN          0.2  Setosa    1.5    1.1
# 3           4.6          NaN           NaN          0.2  Setosa    1.5    1.3
# 4           5.0          3.6           1.4          0.2  Setosa    1.4    1.2

# %%
df.describe()   # not counting nan entries so showing 148
# Out:
#        sepal.length  sepal.width  petal.length  petal.width       sdiff  \
# count    150.000000   148.000000    148.000000   150.000000  150.000000
# mean       5.843333     3.056081      3.789865     1.199333    2.786000
# std        0.828066     0.438648      1.755525     0.762238    0.980072
# min        4.300000     2.000000      1.000000     0.100000    1.000000
# 25%        5.100000     2.800000      1.600000     0.300000    1.800000
# 50%        5.800000     3.000000      4.400000     1.300000    3.000000
# 75%        6.400000     3.325000      5.100000     1.800000    3.600000
# max        7.900000     4.400000      6.900000     2.500000    5.100000
#
#             pdiff
# count  150.000000
# mean     2.558667
# std      1.051696
# min      0.800000
# 25%      1.300000
# 50%      2.900000
# 75%      3.300000
# max      4.700000

# %%
df.dropna()  #drop rows which have nan entries
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  sdiff  \
# 0             5.1          3.5           1.4          0.2     Setosa    1.6
# 1             4.9          3.0           1.4          0.2     Setosa    1.9
# 4             5.0          3.6           1.4          0.2     Setosa    1.4
# 5             5.4          3.9           1.7          0.4     Setosa    1.5
# 6             4.6          3.4           1.4          0.3     Setosa    1.2
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  Virginica    3.7
# 146           6.3          2.5           5.0          1.9  Virginica    3.8
# 147           6.5          3.0           5.2          2.0  Virginica    3.5
# 148           6.2          3.4           5.4          2.3  Virginica    2.8
# 149           5.9          3.0           5.1          1.8  Virginica    2.9
#
#      pdiff
# 0      1.2
# 1      1.2
# 4      1.2
# ...

# %%
c1 = df['sepal.width'].fillna(df['sepal.width'].mean())  # fill nan entries of sepal.width column with mean of that column
c1.head()
# Out:
# 0    3.500000
# 1    3.000000
# 2    3.056081
# 3    3.056081
# 4    3.600000
# Name: sepal.width, dtype: float64
